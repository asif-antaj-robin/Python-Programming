# %% [markdown]
# # input function

# %%
Data = 'python data science and machine learning'

# %%
type(Data)
# Out:
# str

# %%
id(Data)
# Out:
# 2777594507216

# %%
import sys
sys.getsizeof(Data)
# Out:
# 89

# %%
len(Data)
# Out:
# 40

# %%
Data.count('python')
# Out:
# 1

# %%
sub = 'machine learning'
Data.count(sub)
# Out:
# 1

# %%
x  = float(input('Enter your 1st num: '))
y  = float(input('Enter your 2nd num: '))
# Out:
# Enter your 1st num:  50
# Enter your 2nd num:  100

# %% [markdown]
# # Python String Methods

# %%
Data = 'python data science and machine learning'
Data.find('science') #find value from string
# Out:
# 12

# %%
Data.find('machine', 20, 40)
# Out:
# 24

# %%
Data.find('machine', 20, 25) #not exist
# Out:
# -1

# %%
Data.index('machine', 20, 40)
# Out:
# 24

# %%
Data.index('machine', 20, 25) #not exist
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Data.index('machine', 20, 25)
#
# ValueError: substring not found

# %%
Data.lower() #convert all char into lower case
# Out:
# 'python data science and machine learning'

# %%
Data.casefold() #lower
# Out:
# 'python data science and machine learning'

# %%
Data.upper() #convert all char into upper case
# Out:
# 'PYTHON DATA SCIENCE AND MACHINE LEARNING'

# %%
Data.capitalize() #conver only first char into upper case
# Out:
# 'Python data science and machine learning'

# %%
data = "Python Data Science and Machine Learning"

# %%
data.swapcase()
# Out:
# 'pYTHON dATA sCIENCE AND mACHINE lEARNING'

# %%
Data.title()
# Out:
# 'Python Data Science And Machine Learning'

# %%
Data.encode()
# Out:
# b'python data science and machine learning'

# %%
type(Data.encode())
# Out:
# bytes

# %%
Data.split()
# Out:
# ['python', 'data', 'science', 'and', 'machine', 'learning']

# %%
Data.split()[0]
# Out:
# 'python'

# %%
list = Data.split()
list[1]
# Out:
# 'data'

# %%
Data.center(100)
# Out:
# '                              python data science and machine learning                              '

# %%
Data.islower()
# Out:
# True

# %%
Data.isupper()
# Out:
# False

# %%
Data.replace('data','AI')
# Out:
# 'python AI science and machine learning'

# %%
x = 10
y = 100
z = x*y

print("I Have", z, "Taka")
print("I Have {} Taka".format(z))
# Out:
# I Have 1000 Taka
# I Have 1000 Taka

# %% [markdown]
# # Image input

# %%
from IPython.display import Image
Image('Asif Antaj RObin.jpg')

# %% [raw]
# Asif Antaj Robin
# +88 01312531960
# asifantajrobin@gmail.com
# https://www.facebook.com/profile.php?id=100082193912347
